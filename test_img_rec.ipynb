# %%
import cv2
import numpy as np
import random as rng
from matplotlib import pyplot as plt
import imutils 
import easyocr

# %%
# Load image
image_file = 'img\sudoku2.png'
src = cv2.imread(cv2.samples.findFile(image_file))
if src is None:
    print('Could not open or find the image:', image_file)
    exit(0)

# %%
# Pre- process
size = 900
src_resize = cv2.resize(src, (size,size), interpolation = cv2.INTER_AREA)
src_gray = cv2.cvtColor(src_resize, cv2.COLOR_BGR2GRAY)
#src_gray = cv2.blur(src_gray, (3,3))

plt.imshow(src_gray)

# %%
# Find Bounding contours
threshold = 100
canny_output = cv2.Canny(src_gray, threshold, threshold * 2)
keypoints = cv2.findContours(canny_output.copy(), cv2.RETR_LIST , cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints) # grab contours
#contours = sorted(contours, key= cv2.contourArea, reverse=True)[:180] # grab the 10 biggest contours



drawing = np.zeros((canny_output.shape[0], canny_output.shape[1], 3), dtype=np.uint8)
boundRect = []
for i, contour in enumerate(contours):
    if cv2.contourArea(contour) < 10500 and cv2.contourArea(contour) >9000 :
        #print(cv2.contourArea(contour))
        boundRect = cv2.boundingRect(contour)
        color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
        rectangles = cv2.rectangle(drawing, (int(boundRect[0]), int(boundRect[1])),(int(boundRect[0]+boundRect[2]), int(boundRect[1]+boundRect[3])), color, 2)

plt.imshow(drawing)

# %%
sudokuBoard = np.zeros((9, 9))

for i, contour in enumerate(contours):
    if cv2.contourArea(contour) < 10500 and cv2.contourArea(contour) >9000:
        approx = cv2.approxPolyDP(contour, 4, True) # approximate to see if it is square
        mask = np.zeros(src_gray.shape,np.uint8)    # blank mask
        new_image = cv2.drawContours(mask, [approx], 0,255, -1) 
        new_image = cv2.bitwise_and(src_resize,src_resize, mask = mask)


        x,y = np.where(mask == 255)
        x1,y1 = np.min(x), np.min(y)
        x2,y2 = np.max(x), np.max(y)
        cropped_image = src_gray[x1:x2+1,y1:y2+1]

        
        # if new_image canney is not empty
        canny_mask = cv2.Canny(cropped_image[10:len(cropped_image)-10, 10:len(cropped_image)-10], threshold, threshold * 2)

        if not np.all((canny_mask == 0)):
            plt.show()


            reader = easyocr.Reader(['en'])
            result = reader.readtext(cropped_image)
            print(result)
            plt.imshow(new_image)
            #plt.imshow(cropped_image)

            

            if result != []:
                boxX = int((x1+x2)/(2*100))
                boxY = int((y1+y2)/(2*100))
                boxV = result[0][1]
                sudokuBoard[boxX,boxY] = boxV

print(sudokuBoard)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[24, 16], [76, 16], [76, 82], [24, 82]], '9', 0.9412981608746747)]
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# []
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[22, 18], [76, 18], [76, 82], [22, 82]], '8', 0.9626087075093424)]
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[22, 16], [74, 16], [74, 80], [22, 80]], '9', 0.7023732713577506)]
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# []
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[24, 16], [76, 16], [76, 82], [24, 82]], '8', 0.9995359947342867)]
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[29, 17], [73, 17], [73, 79], [29, 79]], '5', 0.9999974966064862)]
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[24,